# %%
import pandas as pd
from sklearn.ensemble import IsolationForest

# Load aggregated yield-weather dataset
corn_weather_state_year = spark.table("workspace.number_one_awesome_team.corn_weather_state_year")

# Select relevant columns and drop rows with missing values
features_df = corn_weather_state_year.select(
    'state', 'year', 'avg_yield', 'avg_temp_max', 'avg_temp_min', 'avg_precip', 'avg_snowfall', 'avg_snow_depth'
).dropna()

# Convert to pandas for ML
features_pd = features_df.toPandas()

if len(features_pd) >= 20:
    # Use avg_precipitation instead of total_precipitation
    X = features_pd[['avg_yield', 'avg_temp_max', 'avg_temp_min', 'avg_precip', 'avg_snowfall', 'avg_snow_depth']]
    clf = IsolationForest(contamination=0.05, random_state=0)
    features_pd['anomaly'] = clf.fit_predict(X)
    anomalies = features_pd[features_pd['anomaly'] == -1]
    display(anomalies[['state', 'year', 'avg_yield', 'avg_temp_max', 'avg_temp_min', 'avg_precip', 'avg_snowfall', 'avg_snow_depth']])
else:
    print('Insufficient sample size for Isolation Forest. Please broaden your selection.')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>state</th><th>year</th><th>avg_yield</th><th>avg_temp_max</th><th>avg_temp_min</th><th>avg_precip</th><th>avg_snowfall</th><th>avg_snow_depth</th></tr></thead><tbody><tr><td>OK</td><td>2011</td><td>4.32</td><td>223.98509535433047</td><td>76.23625420652247</td><td>31.367801139657846</td><td>14.985254831018457</td><td>59.755999498582355</td></tr><tr><td>VT</td><td>2024</td><td>108.5</td><td>-12.592189778257241</td><td>-81.85838567770445</td><td>37.66066558346626</td><td>24.13633668098328</td><td>169.86513581530795</td></tr><tr><td>LA</td><td>2024</td><td>156.70000000000002</td><td>145.57458121816174</td><td>25.752285050784344</td><td>127.38329492325053</td><td>0.17588986783388227</td><td>4.137769742883378</td></tr><tr><td>NY</td><td>2024</td><td>167.2703703703704</td><td>13.448704170016418</td><td>-49.288131772954365</td><td>48.22839145577606</td><td>20.11906327042693</td><td>78.76462239387978</td></tr><tr><td>WY</td><td>2023</td><td>56.6</td><td>106.57676889164861</td><td>-24.849445602528174</td><td>21.326741045987163</td><td>6.989109648821359</td><td>248.98997555748565</td></tr><tr><td>KS</td><td>2024</td><td>96.66489361702128</td><td>29.775031762692706</td><td>-79.80508376651514</td><td>34.00830648121223</td><td>20.86906383556329</td><td>68.04446506605792</td></tr><tr><td>WY</td><td>2019</td><td>59.8</td><td>100.11346382930995</td><td>-31.66344997082979</td><td>22.63103943001271</td><td>13.504860827777952</td><td>226.29776242968455</td></tr><tr><td>IN</td><td>2024</td><td>203.58928571428575</td><td>15.11355184281143</td><td>-50.15193987233447</td><td>45.823813334699956</td><td>6.396549043524335</td><td>27.39214291768424</td></tr><